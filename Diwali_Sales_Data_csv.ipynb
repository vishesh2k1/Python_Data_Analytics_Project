# %% [markdown]
# <a href="https://colab.research.google.com/github/vishesh2k1/Python_Data_Analytics_Project/blob/main/Diwali_Sales_Data_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # data frame(table) working use
import numpy as np  # arrays pe working ke liye
import matplotlib.pyplot as plt  # charts and visualization
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Python_Diwali_Sales_Analysis/Diwali Sales Data.csv', encoding='latin1')

# %%
df.head(10) #show the values
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
df.shape  # rows and column
# Out:
# (11251, 15)

# %%
df.info()  # showing details of rows and column

# %%
df.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
pd.isnull(df)  #to chechking the null values
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
pd.isnull(df).sum()  # to show the null values in column
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df.dropna(inplace=True)  # to drop the null values

# %%
df['Amount'] =df['Amount'].astype('int')  #to change the data type

# %%
df['Amount'].dtypes
# Out:
# dtype('int64')

# %%
df.columns  #to check the column present
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.rename(columns={'Marital_Status':'Shaadi'})  #to rename the column

# %%
df.describe()  # to show the statistical values

# %%
df[['Age','Orders','Amount']].describe()  # check for specific values

# %% [markdown]
# # **Exploratory** **Data  *Analysis*

# %%
ax= sns.countplot(x='Gender', data=df)   # use of seaborn ax vlaue store
for bars in ax.containers:   # making container to count all values
  ax.bar_label(bars)     # to makes labes in chart

# %%
sales_gen=df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(x='Gender', y='Amount', data=sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# from above graph we can see that most of the buyes are females and even the purchasing power of females are greater then ***man***

# %% [markdown]
# **Age**

# %%
ax=sns.countplot( data=df, x='Age Group',hue= 'Gender')
for bars in ax.containers:
  ax.bar_label(bars)

# %%
#tOTAL Amount  VS Age Group

sales_age=df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.barplot(x='Age Group', y='Amount', data=sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# from above graphs most of the buyers are of age group b/w 26-35 yrs females

# %% [markdown]
# # State

# %%
df.columns

# %%
#total number of orders from top 10 states
sales_states=df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(18,5)})   # give the size of chart(width,height)
sns.barplot(x='State', y='Orders', data=sales_states)
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %%
#total amount/sales from top 10 sates

sales_states=df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(18,5)})
sns.barplot(x='State', y='Amount', data=sales_states)
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# from above graphs we can see that most of the orders & total sales / amount are from Uttar Pradesh ,Mahrashtra and karnataka respectively

# %% [markdown]
#  **Marital Status**

# %%
ax=sns.countplot(data=df, x='Marital_Status',palette=['#FF5733', '#33C3FF'])
sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
  ax.bar_label(bars)
# Out:
# <ipython-input-48-8e844c1061da>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(data=df, x='Marital_Status',palette=['#FF5733', '#33C3FF'])

# %%
# on the bases of marital_status/gender

sales_state=df.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data=sales_state, x='Marital_Status', y='Amount', hue='Gender')
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# ### From above graphs we can see most of the buyers are married(women) and they have high purchasing power

# %% [markdown]
# **Occupation**

# %%
sns.set(rc={'figure.figsize':(23,5)})
ax=sns.countplot(data=df, x='Occupation',palette='pastel' )
for bars in ax.containers:
  ax.bar_label(bars)
# Out:
# <ipython-input-56-c6dfdca89c01>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(data=df, x='Occupation',palette='pastel' )

# %%
sales_state=df.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state, x='Occupation', y='Amount' ,palette='pastel')
# Out:
# <ipython-input-58-049c273b53d7>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state, x='Occupation', y='Amount' ,palette='pastel')
# <Axes: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# ### From above graphs see that most of the buyers are working in IT ,Healthcare and aviation sector

# %% [markdown]
# **Product Category**

# %%
sns.set(rc={'figure.figsize':(28,5)})
ax=sns.countplot(data=df, x='Product_Category',palette='pastel')
for bars in ax.containers:
  ax.bar_label(bars)
# Out:
# <ipython-input-66-f8562a9dc081>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.countplot(data=df, x='Product_Category',palette='pastel')

# %%
sales_state=df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
sns.set(rc={'figure.figsize':(35,5)})
sns.barplot(data=sales_state, x='Product_Category', y='Amount' ,palette='pastel')
# Out:
# <ipython-input-70-e502940b8399>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state, x='Product_Category', y='Amount' ,palette='pastel')
# <Axes: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# ## From the above graph we can se that most of the sold products are from Food ,Clothing and Electronics category

# %%
# to see top selling product
sales_state= df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data=sales_state, x='Product_ID', y='Orders', palette='pastel')
# Out:
# <ipython-input-75-1bb1f4f7a0a7>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=sales_state, x='Product_ID', y='Orders', palette='pastel')
# <Axes: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# **Conclusion:**

# %% [markdown]
# # **Married women age 26-30 yrs from up Mahrastra and Karnatka eoking in IT sector ,Healthcare and Aviation are likely buts producs from Food, clothing and electronics category**
